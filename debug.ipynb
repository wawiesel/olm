# %%
import numpy as np
import scale.olm as olm
# Out:
# initialized scale.olm.check
# initialized scale.olm

# %%
res=dict()
for f in ['data/w17x17.h5','data/ge10x10-8.h5','data/vver440.h5','data/mox_w17x17.h5']:
    options = type('', (), {})()
    options.eps0=1e-20
    options.epsa=1e-1
    options.epsr=1e-1
    c=olm.check.grid_gradient(olm.Archive(f),options)
    res[f]=c
# Out:
# loading archive file: data/w17x17.h5
# 100%|███████████████████████████████████████████| 11/11 [00:05<00:00,  2.14it/s]
# grid_gradient
# [[0.0, 0.125, 0.1875, 0.3125, 0.4375, 0.5625, 0.6875, 0.8125, 0.9375, 1.0], [0.0, 1.0], [0.0, 0.00048484848, 0.012606061, 0.036363635, 0.060606062, 0.09090909, 0.12727273, 0.16363636, 0.2, 0.23636363, 0.27272728, 0.3090909, 0.34545454, 0.38181818, 0.4181818, 0.45454547, 0.4909091, 0.5272727, 0.56363636, 0.6, 0.6363636, 0.6727273, 0.7090909, 0.74545455, 0.7818182, 0.8181818, 0.8545455, 0.8909091, 0.92727274, 0.96363634, 1.0]]
# 100%|███████████████████████████████████| 57954/57954 [00:45<00:00, 1263.67it/s]
# initializing checkinfo
# loading archive file: data/ge10x10-8.h5
# 100%|███████████████████████████████████████████| 51/51 [00:39<00:00,  1.28it/s]
# grid_gradient
# [[0.0, 0.125, 0.1875, 0.3125, 0.4375, 0.5625, 0.6875, 0.8125, 0.9375, 1.0], [0.0, 0.24999999999999997, 0.5, 0.7499999999999999, 1.0], [0.0, 0.0003030303, 0.0063636363, 0.018181818, 0.030303031, 0.045454547, 0.06363636, 0.08181818, 0.1, 0.11818182, 0.13636364, 0.15454546, 0.17272727, 0.19090909, 0.2090909, 0.22727273, 0.24545455, 0.27272728, 0.3090909, 0.34545454, 0.38181818, 0.4181818, 0.45454547, 0.4909091, 0.5272727, 0.56363636, 0.6, 0.6363636, 0.6727273, 0.7090909, 0.74545455, 0.7818182, 0.8181818, 0.8545455, 0.8909091, 0.92727274, 0.96363634, 1.0]]
# 100%|████████████████████████████████████| 57954/57954 [01:03<00:00, 908.13it/s]
# initializing checkinfo
# loading archive file: data/vver440.h5
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.27it/s]
# grid_gradient
# [[0.0, 0.3999999999999999, 1.0], [0.0, 1.0], [0.0, 0.0003878788, 0.012509091, 0.036363635, 0.060606062, 0.09090909, 0.12727273, 0.16363636, 0.2, 0.23636363, 0.27272728, 0.3090909, 0.34545454, 0.38181818, 0.4181818, 0.45454547, 0.4909091, 0.5272727, 0.56363636, 0.6, 0.6363636, 0.6727273, 0.7090909, 0.74545455, 0.7818182, 0.8181818, 0.8545455, 0.8909091, 0.92727274, 0.96363634, 1.0]]
# 100%|███████████████████████████████████| 57954/57954 [00:35<00:00, 1612.29it/s]
# initializing checkinfo
# loading archive file: data/mox_w17x17.h5
# 100%|███████████████████████████████████████████| 16/16 [00:02<00:00,  5.90it/s]
# grid_gradient
# [[0.0, 0.25, 0.5, 0.75, 1.0], [0.0, 1.0], [0.0, 0.5, 1.0], [0.0, 0.00048484848, 0.012606061, 0.036363635, 0.060606062, 0.09090909, 0.12727273, 0.16363636, 0.2, 0.23636363, 0.27272728, 0.3090909, 0.34545454, 0.38181818, 0.4181818, 0.45454547, 0.4909091, 0.5272727, 0.56363636, 0.6, 0.6363636, 0.6727273, 0.7090909, 0.74545455, 0.7818182, 0.8181818, 0.8545455, 0.8909091, 0.92727274, 0.96363634, 1.0]]
# 100%|███████████████████████████████████| 57954/57954 [00:53<00:00, 1082.03it/s]
# initializing checkinfo

# %%
for f in res:
    print(f,res[f].q1,res[f].q2)
    olm.check.plot_grid_gradient_hist(res[f])
    print('---')
# Out:
# /Users/ww5/dev/scale/olm/scale/olm/check/check.py:83: RuntimeWarning: divide by zero encountered in log10
#   plt.hist2d(np.log10(info.rhist),np.log10(info.ahist),bins=np.linspace(-40,20,100),cmin=1,alpha=0.2)
# data/w17x17.h5 0.6302488947172662 0.9261490914249999
# ---
# data/ge10x10-8.h5 0.3724083851943879 0.8712971590495143
# ---
# data/vver440.h5 0.8021534320323015 0.954244745832902
# ---
# data/mox_w17x17.h5 0.6421245729371571 0.9303182265244849
# ---

# %%
j=41114 #transition
ne=0 #enrichment axis
nm=1 #moderator density axis
nb=2 #burnup axis
print(*archive.axes_values)
y=archive.coeff[...,:,j]
yin=y #/archive.coeff[...,0:1,j] #normalize to t=0
print(np.shape(yin))
ib=None
for ie in range(archive.axes_shape[ne]):
    for im in range(archive.axes_shape[nm]):
        plt.plot(archive.axes_values[nb],yin[ie,im,:],marker='.')
plt.title('coefficient vs. burnup')
plt.show()

ie=None
for ib in range(archive.axes_shape[nb]):
    for im in range(archive.axes_shape[nm]):
        plt.plot(archive.axes_values[ne],yin[:,im,ib],marker='.')
plt.ylabel('I-127 fission yield [barns]')
plt.xlabel('enrichment [U-235 wt.%]')
plt.show()

e_list=list()
for ie in range(archive.axes_shape[ne]):
    e = archive.axes_values[ne][ie]
    c='-'
    plt.plot(archive.axes_values[nb],y[ie,0,:],c,marker='.')
    
    e_list.append(e)
plt.legend(e_list)
plt.ylabel('I-127 fission yield [barns]')
plt.xlabel('burnup [MWd]')
plt.show()

bu_list=list()
for ib in range(archive.axes_shape[nb]):
    bu = archive.axes_values[nb][ib]
    c='-'
    plt.plot(archive.axes_values[ne],y[:,0,ib],c,marker='.')
    
    bu_list.append(bu)
plt.legend(bu_list)
plt.ylabel('I-127 fission yield [barns]')
plt.show()

# %%
rel_axes=list()
for x_list in archive.axes_values:
    dx=x_list[-1]-x_list[0]
    x0 = x_list[0]
    z=list()
    for x in x_list:
        z.append((x-x0)/dx)
    rel_axes.append(z)
print(rel_axes)

# %%
yp=np.asarray(np.gradient(yin,*rel_axes))
print(np.shape(yp))

#gradients
#burnup plots
ib=None
for ie in range(archive.axes_shape[ne]):
    for im in range(archive.axes_shape[nm]):
        #print(archive.axes_values[ne][ie],archive.axes_values[nm][im],yp[0,ie,im,:])
        plt.plot(archive.axes_values[nb],yp[0,ie,im,:])
plt.title('gradients vs. burnup')
plt.show()

#enrichment
ie=None
for im in range(archive.axes_shape[nm]):
    for ib in range(archive.axes_shape[nb]):
        plt.plot(archive.axes_values[ne],yp[0,:,im,ib])
plt.title('gradients vs. enrichment')
plt.show()

# %%
for i in range(2):
    ypp=np.asarray(np.gradient(yp[i,:,:],axis=i))
    print(np.shape(ypp))
    for j in range(10):
        plt.plot(archive.axes_values[2],ypp[j,0,:])
plt.title('vs. burnup')
plt.show()

# %%
for i in range(3):
    ypp=np.asarray(np.gradient(yp[i,:,:,:],axis=2))
    print(np.shape(ypp))
    for j in range(10):
        plt.plot(archive.axes_values[2],ypp[j,0,:])
    plt.title(archive.axes_names[i])
    plt.show()

# %%
ax=0
for i in range(3):
    for j in range(i+1):
        ypp=np.asarray(np.gradient(yp[i,...],axis=j))
        print(np.shape(ypp))
        im=0
        for ib in range(archive.axes_shape[nb]):
            d=(slice(None),im,ib)
            plt.plot(archive.axes_values[ne],ypp[d])
        plt.title('d2[-]/d['+archive.axes_names[i]+'] d['+archive.axes_names[j]+']')
        plt.xlabel('enrichment')
        plt.show()

        im=0
        ib=slice(None)
        for ie in range(archive.axes_shape[ne]):
            d=(ie,im,ib)
            plt.plot(archive.axes_values[nb],ypp[d])
        plt.title('d2[-]/d['+archive.axes_names[i]+'] d['+archive.axes_names[j]+']')
        plt.xlabel('burnup')
        plt.show()

# %%
rel_axes=list()
for x_list in archive.axes_values:
    dx=x_list[-1]-x_list[0]
    x0 = x_list[0]
    z=list()
    for x in x_list:
        z.append((x-x0)/dx)
    rel_axes.append(z)
print(rel_axes)

deriv=list()
rhist=list()
ahist=list()
khist=list()
for k in range(archive.ncoeff):
    y=archive.coeff[...,k]
    yp=np.asarray(np.gradient(y,*rel_axes))
    n=len(archive.axes_shape)
    pack=[None]*n
    for i in range(n):
        max0 = np.amax( yp[i,...] )
        min0 = np.amin( yp[i,...] )
        ypr = yp[i,...]/(y+eps)
        rmax0 = np.amax( ypr )
        rmin0 = np.amin( ypr )
        diff_list=list()
        for j in range(n):
            ydr = np.absolute(np.diff(ypr,axis=j))
            yd = np.absolute(np.diff(yp[i,...],axis=j))
            vr = np.amax(ydr)
            diff_list.append( vr )
            rhist.append( vr )
            va = np.amax(yd)
            ahist.append( va )
            khist.append( k )
        pack[i]={'min':min0,'max':max0,'rmin':rmin0,'rmax':rmax0, 'diff': diff_list}
    deriv.append(pack)
ahist = np.asarray(ahist)
rhist = np.asarray(rhist)
khist = np.asarray(khist)

# %%
deriv[10161]

# %%
plt.hist(rhist, bins=np.linspace(0,np.amax(rhist),100), histtype=u'step',density=False,log=True)
plt.show()

# %%
plt.hist(ahist, bins=np.linspace(0,np.amax(ahist),100), histtype=u'step',density=False,log=True)
plt.show()

# %%
plt.scatter(np.log10(rhist),np.log10(ahist),color='black',s=0.1,alpha=0.05)
plt.xlabel(r'$\log \tilde{h}_{ijk}$')
plt.ylabel(r'$\log h_{ijk}$')
plt.xlim(-40,20)
plt.ylim(-40,20)
plt.show()

# %%
rmin=1e-1
amin=1e-1
ind = (rhist>rmin) | (ahist>amin)
plt.hist2d(np.log10(rhist),np.log10(ahist),bins=np.linspace(-40,20,100),cmin=1,alpha=0.5)
h=plt.hist2d(np.log10(rhist[ind]),np.log10(ahist[ind]),bins=np.linspace(-40,20,100),cmin=1,alpha=1.0)
plt.colorbar(h[3])
plt.xlabel(r'$\log \tilde{h}_{ijk}$')
plt.ylabel(r'$\log h_{ijk}$')
plt.grid()
plt.show()

# %%
ts=archive.h5['incident']['neutron']['TransitionStructure']
dc=archive.h5['decay']

# %%
ts['transition_ids'][41611]

# %%
ts['parent_positions'][41611]

# %%
dc['nuclide_list'][1021-1]
