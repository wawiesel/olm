# %%
import numpy as np
import sys
root='/Users/ww5/dev/scale/olm'
sys.path.append(root)
import scale.olm as olm
from pathlib import Path

# %%
test_dir=Path(root+'/examples/quick2/_build/arpdata.arc.h5')
archive_data=olm.common.Archive(test_dir)
c=olm.check.GridGradient(eps0=1e-20,epsa=1e-1,epsr=1e-1)
c.run(archive_data)
res=c
# Out:
# 2023-08-17 01:42:24 [info     ] Loading archive file=/Users/ww5/dev/scale/olm/examples/quick2/_build/arpdata.arc.h5
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 22.65it/s]
# 2023-08-17 01:42:25 [info     ] Running GridGradient check with params={"eps0": 1e-20, "epsa": 0.1, "epsr": 0.1}
# 2023-08-17 01:42:25 [info     ] Finished computing relative values on axes
# 2023-08-17 01:42:25 [info     ] Finished reshaping coefficients
# 2023-08-17 01:42:25 [info     ] Computing grid gradients ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 57954/57954 [00:30<00:00, 1893.32it/s]
# 2023-08-17 01:42:55 [info     ] Finished computing grid gradients
# 2023-08-17 01:42:55 [info     ] Completed GridGradient with q1=0.20 and q2=0.85

# %%
 olm.common.plot_hist(res)
# Out:
# /Users/ww5/dev/scale/olm/scale/olm/common.py:427: RuntimeWarning: divide by zero encountered in log10
#   np.log10(x.rhist),
# /Users/ww5/dev/scale/olm/scale/olm/common.py:428: RuntimeWarning: divide by zero encountered in log10
#   np.log10(x.ahist),
